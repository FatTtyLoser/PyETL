# %% [markdown]
# # [Crawler] PttGossiping 爬蟲實作
# ---
# - Author: 彼獅.Belion(FatTtyLoser.FTL)
#
#   ---
#
# - Article:
#     Blog post: [[Crawler] PttGossiping 爬蟲實作](https://fatttyloser.coderbridge.io/2021/11/17/POG-PttGossiping/)
#     HackMD post: [[Crawler] PttGossiping 爬蟲實作](https://hackmd.io/@FatTtyLoser/POG_PttGossiping)
#
#   ---
#
# - Information:
#     Belion blog: [Belion](https://fatttyloser.coderbridge.io/)
#     HackMD: [彼獅.Belion](https://hackmd.io/@FatTtyLoser)

# %% [markdown]
# ### Install packges

# %%
# !pip install fake_useragent
# !pip install requests
# !pip install pandas
# !pip install bs4
# Out:
# Requirement already satisfied: fake_useragent in c:\programdata\anaconda3\envs\core_1\lib\site-packages (0.1.11)
# Requirement already satisfied: requests in c:\programdata\anaconda3\envs\core_1\lib\site-packages (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\core_1\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\envs\core_1\lib\site-packages (from requests) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\envs\core_1\lib\site-packages (from requests) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\core_1\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\envs\core_1\lib\site-packages (1.3.4)
# Requirement already satisfied: numpy>=1.17.3 in c:\programdata\anaconda3\envs\core_1\lib\site-packages (from pandas) (1.21.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\envs\core_1\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\envs\core_1\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\core_1\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: bs4 in c:\programdata\anaconda3\envs\core_1\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\envs\core_1\lib\site-packages (from bs4) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\envs\core_1\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)

# %% [markdown]
# ### Import modules

# %%
# 引入我們所需要的模組套件
from fake_useragent import UserAgent
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time
import re
import os

# %% [markdown]
# ### Setting

# %%
# 設定儲存目標資料夾
path = r'.\\Ptt_Gossiping_Article'
if not os.path.exists(path):
    os.mkdir(path)

# 設定爬蟲程式偽裝瀏覽器的參數
userAgent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36'
headers = {
    'User-Agent' : UserAgent().random
}
cookie = {'over18':'1'}

# Ptt網頁版 Gossiping版 主頁index
url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
# 設定頁數
n = 3

# %% [markdown]
# ### Index request

# %%
for i in range(0, n):
    res = requests.get(url, headers=headers, cookies=cookie)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    # 同頁內的文章標題取出各文章 url
    title = soup.select('div[class="title"]')
    print(title)
    print('==========')
    
    url = 'https://www.ptt.cc'+soup.findAll('a', class_="btn wide")[1]['href']
# Out:
# [<div class="title">
# <a href="/bbs/Gossiping/M.1637912033.A.833.html">Re: [新聞] 蘇揆：半年治安不改善 下台退政壇</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637912061.A.674.html">Re: [問卦] HTC怎麼把自己搞成這樣的？</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637912073.A.8D3.html">[問卦] 為什麼每年都有高麗菜超種新聞??????</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637912078.A.72D.html">Re: [問卦] 大躺平！ 美國爆單月超過400萬人離職潮</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637912150.A.5B8.html">[問卦] 最頂的秘密結社是哪個?</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637912223.A.56A.html">[問卦] 為啥台式甜甜圈流行不起來?</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637912235.A.978.html">[新聞] 網紅暨大演講「感謝狀丟垃圾桶」學生全炸</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637912303.A.7D1.html">Re: [新聞] 新北綠委開記者會反核四 挺核人士嗆：魔</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637912328.A.3F8.html">[問卦] 喝茶吃魚有錯嗎</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637912570.A.6ED.html">[問卦] 台中死胖子的招待所都用來幹嘛?</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637912598.A.AB5.html">Re: [新聞] 獨／北捷APP明年起限會員查到站時間　</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637912627.A.77A.html">[問卦] 有沒有原本沒事，結果體檢出來更多病的?</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637912638.A.514.html">[問卦] 丁小芹的八卦?</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637912648.A.EEB.html">Re: [新聞] 網紅暨大演講「感謝狀丟垃圾桶」學生全炸</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637912724.A.106.html">Re: [問卦] Meteo流光鋼琴詐騙2500萬 嘖嘖平台毫無責</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637912755.A.99C.html">Re: [爆卦] 美國議員來台稱台灣共和國</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637
</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637910718.A.0F5.html">Re: [問卦] 驚!溫妮以前長這樣??</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637910830.A.8F8.html">Re: [問卦] Meteo流光鋼琴詐騙2500萬 嘖嘖平台毫無責</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637910862.A.3AF.html">[問卦] 黑人葛哥</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637910868.A.822.html">[問卦] 台灣足球沒發展起來到底是誰的問題！</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637910912.A.67F.html">[問卦] 南部都沒在戴口罩了？</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637910939.A.FF0.html">[問卦] 吃很純的毒品是什麼感覺？？？</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637910958.A.1C3.html">Re: [爆卦] 李天豪談「四萬換一元」</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637910985.A.63A.html">[問卦] 張旭老師的八卦</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637911018.A.FA2.html">[問卦] 怎麼用筆電賺錢啊？</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637911051.A.562.html">[新聞] 青山宮備鹹光餅蓋4個不同意 總統、林昶佐</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637911172.A.472.html">Re: [問卦] 你們身邊有看過+9改邪歸正的嗎?</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1637911183.A.59E.html">[新聞] 妹子賣烤蛋捲這招太狠　裡面都沒穿！「一罩爆乳」誘惑聚人心</a>
# </div>]
# ==========

# %% [markdown]
# ### Title resub
# ：試著將 title 透過 python 正則化將特殊字元刪除，使得Win10可以儲存。
# ( `process_time` 可以了解程式執行時間。)

# %%
start = time.process_time()
title = 'Re: [問卦] 你們是笨蛋嗎：？'

sc = [':', '/', '*', '"', '>', '<', '|', '?', '：', ' ']
print(title)

for SpecialCha in sc:
    if SpecialCha in title:
        title = re.sub("\<|\'|\?|\ |\>|\*|\:|\"|\？|\：","",title)
    else:
        pass
print(title)

end = time.process_time()
print(end - start)
# Out:
# Re: [問卦] 你們是笨蛋嗎：？
# Re[問卦]你們是笨蛋嗎
# 0.0

# %% [markdown]
# ### Article content
#
# ：試著將一篇文章的內文、文章資訊、留言區，整理成想要的格式。

# %%
url = 'https://www.ptt.cc/bbs/Gossiping/M.1636316268.A.A83.html'

res = requests.get(url, headers=headers, cookies=cookie)
html = res.text
soup = BeautifulSoup(html, 'html.parser')
title = soup.select('div[class="title"]')


push_info_list = soup.select('div[class="push"] span')
description_list = soup.select('div[class="article-metaline"] span')
for i, item in enumerate(description_list):
    if (i+1)%6 == 2:
        Article_author = item.text
    if (i+1)%6 == 4:
        Article_title = item.text
    if (i+1)%6 == 0:
        Article_datetime = item.text

Push = 0
Boo = 0
Score = 0 
for info in push_info_list:
    if '推' in info.text:
        Push += 1
    if '噓' in info.text:
        Boo += 1
Score = Push - Boo
Commtes_author = []
Commtes_comment = []
Commtes_IP = []
for n, info in enumerate(push_info_list):
    if (n+1)%4 == 2:
        Commtes_author.append(info.text)
    if (n+1)%4 == 3:
        Commtes_comment.append(info.text)
    if (n+1)%4 == 0:
        Commtes_IP.append(info.text)
content = soup.select('div[id="main-content"]')[0].text.split('--')[0]
content += '\n----------\n'
content += '作者：%s\n' %(Article_author)
content += '標題：%s\n' %(Article_title)
content += '時間：%s\n' %(Article_author)
content += '推：%s\n' %(Push)
content += '噓：%s\n' %(Boo)
content += '分數：%s' %(Score)
content += '\n----------\n'
for n in range(0,len(Commtes_author)):
    content += Commtes_author[n]
    content += Commtes_comment[n]
# laugh8562: 超熱|  101.12.29.183 11/08 07:49
# chu: 我還在開電風扇 是冷在哪裡|  111.71.212.61 11/08 07:55
# imtaku: 台灣有神功護體，感覺不會冷啊！|   110.26.41.93 11/08 08:08
# horseorange: 半夜雨超大的|  223.137.31.55 11/08 08:23
# windmk2: 中和這邊感覺雨盆打翻了|   101.12.49.21 11/08 09:01
# cymtrex: 冷氣電扇+1|   42.77.57.231 11/08 09:31
# Jyuner: 開冷氣+1| 223.136.93.255 11/08 09:58

# %% [markdown]
# ## Complete code

# %%
# 引入我們所需要的模組套件
from fake_useragent import UserAgent
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time
import re
import os

# 設定儲存目標資料夾
path = r'.\\Ptt_Gossiping_Article'
if not os.path.exists(path):
    os.mkdir(path)

# 設定爬蟲程式偽裝瀏覽器的參數
userAgent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36'
headers = {
    'User-Agent' : UserAgent().random
}
cookie = {'over18':'1'}

# Ptt網頁版 Gossiping版 主頁index
url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
# 設定頁數
n = 3
# 翻頁loop
for i in range(0, n):
    res = requests.get(url, headers=headers, cookies=cookie)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    # 同頁內的文章標題取出各文章 url
    title = soup.select('div[class="title"]')
    # 訪問各文章 loop
#     time.sleep(10)
    for eachArticle in title:
        try:
#             利用 try&except 訪問未被刪除的文章，否則會 return 刪除資訊
            try:
                each_articleUrl = 'https://www.ptt.cc' + eachArticle.select('a')[0]['href']
                print(each_articleUrl)
            except:
                print(eachArticle)
                print("============================================")
            each_articleRes = requests.get(url=each_articleUrl, headers=headers, cookies=cookie)
#             time.sleep(10)
            each_articleHtml = each_articleRes.text
            each_articleSoup = BeautifulSoup(each_articleHtml, 'html.parser')
            each_articleAuthor = each_articleSoup.select('span[class="article-meta-value"]')[0].text
            each_articleTitle = each_articleSoup.select('span[class="article-meta-value"]')[2].text
            each_articleText = each_articleSoup.select('div[id="main-content"]')[0].text.split('--')[0]
            # [踩坑] 由於 windows 檔案名稱不得有特定的特殊字元 所以直接刪除特殊字元
            if ':' and '/' and '*' and '"' and '>' and '<' and '|' and '?' and '：' and ' ' in each_articleTitle:
                each_articleTitle = re.sub("\<|\'|\?|\ |\>|\*|\:|\"|\？|\：|\||\/|\//","",each_articleTitle)
            else:
                pass
            # 若只想要儲存內文作為文字分析需求 預處理刪除網址連結
#             if 'https://' in each_articleText:
#                 each_articleText = each_articleText.split('\n')
#                 for h in each_articleText[0:]:
#                     if 'https://' in h:
#                         each_articleText.remove(h)
#                 each_articleText = "".join(map(str, each_articleText))
#             else :
#                 pass
            # 本篇文章 information
            push_info_list = each_articleSoup.select('div[class="push"] span')
            description_list = each_articleSoup.select('div[class="article-metaline"] span')
            for i, item in enumerate(description_list):
                if (i+1)%6 == 2:
                    Article_author = item.text
                if (i+1)%6 == 4:
                    Article_title = item.text
                if (i+1)%6 == 0:
                    Article_datetime = item.text
            # 統計推噓文
            Push = 0
            Boo = 0
            Score = 0 
            for info in push_info_list:
                if '推' in info.text:
                    Push += 1
                if '噓' in info.text:
                    Boo += 1
            Score = Push - Boo
            # 留言區整理
            Commtes_author = []
            Commtes_comment = []
            Commtes_IP = []
            for n, info in enumerate(push_info_list):
                if (n+1)%4 == 2:
                    Commtes_author.append(info.text)
                if (n+1)%4 == 3:
                    Commtes_comment.append(info.text)
                if (n+1)%4 == 0:
                    Commtes_IP.append(info.text)
            # 將文章內文加上文章 info
            each_articleText += '\n----------\n'
            each_articleText += '作者：%s\n' %(Article_author)
            each_articleText += '標題：%s\n' %(Article_title)
            each_articleText += '時間：%s\n' %(Article_author)
            each_articleText += '推：%s\n' %(Push)
            each_articleText += '噓：%s\n' %(Boo)
            each_articleText += '分數：%s' %(Score)
            each_articleText += '\n----------\n'
            # 將文章內文加上留言區
            for n in range(0,len(Commtes_author)):
                each_articleText += Commtes_author[n]
                each_articleText += Commtes_comment[n]
                each_articleText += '|'+Commtes_IP[n]
            # 儲存文章到指定 Path
            try:
                if os.path.isfile(r'%s\\\%s.txt' % (path, each_articleTitle)):
                    filename = each_articleTitle+'!'+each_articleAuthor
                    with open(r'%s\\\%s.txt' % (path, filename), 'w', encoding='utf-8') as w:
                        w.write(each_articleText)
                else:
                    with open(r'%s\\\%s.txt' % (path, each_articleTitle), 'w', encoding='utf-8') as w:
                        w.write(each_articleText)
                print()
        # 偵錯放在 loop 最後透過 except print 出 方便檢查 log
            except FileNotFoundError as e:
                print(each_articleTitle)
                print(e.args)
                print('==============')
            except OSError as e:
                print(each_articleTitle)
                print(e.args)
                print('==============')
        except AttributeError as e:
            print(each_articleTitle)
            print(e.args)
            print('==============')
    # 翻頁
    url = 'https://www.ptt.cc'+soup.findAll('a', class_="btn wide")[1]['href']
# Out:
# https://www.ptt.cc/bbs/Gossiping/M.1637898366.A.EC5.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898473.A.C29.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898524.A.767.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898529.A.DFA.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898562.A.2FA.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898578.A.B9B.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898583.A.C5F.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898666.A.5D3.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898673.A.3A2.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898678.A.73D.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898771.A.CC1.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898779.A.737.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898790.A.DFB.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898849.A.630.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898930.A.399.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637899018.A.131.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637899033.A.8FF.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637899039.A.F54.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637899041.A.B44.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637247210.A.773.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637406544.A.E72.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637425085.A.07D.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637854550.A.CF6.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637860343.A.58A.html
#
# <div class="title">
#
# 				(本文已被刪除) [onolll]
#
# 			</div>
# ===========
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897512.A.DFC.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897540.A.751.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897543.A.7EC.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897666.A.968.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897769.A.97F.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897925.A.9D9.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898054.A.B05.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898086.A.3FA.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898106.A.347.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898110.A.42F.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898118.A.685.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898156.A.25C.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898278.A.29B.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898324.A.CCA.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898327.A.99D.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898335.A.E0B.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898343.A.BEF.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898361.A.86D.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637898365.A.68A.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637896814.A.DFD.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637896833.A.3C8.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637896902.A.BAB.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637896975.A.757.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637896977.A.4FB.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897019.A.8C9.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897068.A.32B.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897081.A.BAC.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897089.A.110.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897093.A.50A.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897115.A.C94.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897118.A.E30.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897246.A.FBD.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897301.A.90C.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897301.A.874.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897313.A.56C.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897356.A.E46.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897395.A.168.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897414.A.BA0.html
#
# https://www.ptt.cc/bbs/Gossiping/M.1637897444.A.D46.html
